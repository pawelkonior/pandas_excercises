# %%
import os
import pandas as pd

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'ceny_produktow.csv'), sep=';')
df.head()
# Out:
#                  Nazwa Rodzaje towarów Jednostka miary  ID grupy  \
# 0         PODKARPACKIE             NaN              zł         2
# 1              ŁÓDZKIE             NaN              zł         4
# 2   KUJAWSKO-POMORSKIE             NaN              zł         2
# 3         DOLNOŚLĄSKIE             NaN              zł         2
# 4  WARMIŃSKO-MAZURSKIE             NaN              zł         2
#
#                     Rodzaje produktów  Wartosc     Data
# 0  szynka wieprzowa gotowana - za 1kg    21.37   2013-3
# 1                      chleb - za 1kg      NaN   2018-2
# 2  kiszka kaszana jęczmienna - za 1kg     3.55  2019-12
# 3        kurczęta patroszone - za 1kg     6.14   2019-2
# 4            salceson Włoski - za 1kg     5.63   2002-3

# %%
df.columns
# Out:
# Index(['Nazwa', 'Rodzaje towarów', 'Jednostka miary', 'ID grupy',
#        'Rodzaje produktów', 'Wartosc', 'Data'],
#       dtype='object')

# %%
cols = pd.read_csv(os.path.join('..', 'datasets', 'ceny_produktow_renamed.csv'), sep=';').columns

# %%
new_cols = {old_col: new_col for old_col, new_col in zip(df.columns, cols)}

# %%
new_cols
# Out:
# {'Nazwa': 'province',
#  'Rodzaje towarów': 'product_types',
#  'Jednostka miary': 'currency',
#  'ID grupy': 'product_group_id',
#  'Rodzaje produktów': 'product_line',
#  'Wartosc': 'value',
#  'Data': 'date'}

# %%
# df = df.rename(columns=new_cols)
df.rename(columns=new_cols, inplace=True)

# %%
df
# Out:
#                    province  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149937          MAŁOPOLSKIE
# 149938  WARMIŃSKO-MAZURSKIE
# 149939          MAZOWIECKIE
#
#                                             product_types currency  \
# 0                                                     NaN       zł
# 1                                                     NaN       zł
# 2                                                     NaN       zł
# 3                                                     NaN       zł
# 4                                                     NaN       zł
# ...                                                   ...      ...
# 149935                                                NaN       zł
# 149936  cukier biały z buraków cukrowych, workowany - ...       zł
# ...

# %%
new_cols.keys()
# Out:
# dict_keys(['Nazwa', 'Rodzaje towarów', 'Jednostka miary', 'ID grupy', 'Rodzaje produktów', 'Wartosc', 'Data'])

# %%
df.columns = list(new_cols)

# %%
df
# Out:
#                       Nazwa  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149937          MAŁOPOLSKIE
# 149938  WARMIŃSKO-MAZURSKIE
# 149939          MAZOWIECKIE
#
#                                           Rodzaje towarów Jednostka miary  \
# 0                                                     NaN              zł
# 1                                                     NaN              zł
# 2                                                     NaN              zł
# 3                                                     NaN              zł
# 4                                                     NaN              zł
# ...                                                   ...             ...
# 149935                                                NaN              zł
# ...

# %%
df.Nazwa
# Out:
# 0                PODKARPACKIE
# 1                     ŁÓDZKIE
# 2          KUJAWSKO-POMORSKIE
# 3                DOLNOŚLĄSKIE
# 4         WARMIŃSKO-MAZURSKIE
#                  ...
# 149935     KUJAWSKO-POMORSKIE
# 149936                ŁÓDZKIE
# 149937            MAŁOPOLSKIE
# 149938    WARMIŃSKO-MAZURSKIE
# 149939            MAZOWIECKIE
# Name: Nazwa, Length: 149940, dtype: object

# %%
df["Jednostka miary"]
# Out:
# 0         zł
# 1         zł
# 2         zł
# 3         zł
# 4         zł
#           ..
# 149935    zł
# 149936    zł
# 149937    zł
# 149938    zł
# 149939    zł
# Name: Jednostka miary, Length: 149940, dtype: object

# %%
df_products = pd.read_csv(os.path.join('..', 'datasets', 'ceny_produktow_renamed.csv'), sep=';')
df_products.head()
# Out:
#               province product_types currency  product_group_id  \
# 0         PODKARPACKIE           NaN       zł                 2
# 1              ŁÓDZKIE           NaN       zł                 4
# 2   KUJAWSKO-POMORSKIE           NaN       zł                 2
# 3         DOLNOŚLĄSKIE           NaN       zł                 2
# 4  WARMIŃSKO-MAZURSKIE           NaN       zł                 2
#
#                          product_line  value     date
# 0  szynka wieprzowa gotowana - za 1kg  21.37   2013-3
# 1                      chleb - za 1kg    NaN   2018-2
# 2  kiszka kaszana jęczmienna - za 1kg   3.55  2019-12
# 3        kurczęta patroszone - za 1kg   6.14   2019-2
# 4            salceson Włoski - za 1kg   5.63   2002-3

# %%
df_products = df_products.loc[df_products['province'] == 'POLSKA']

# %%
import numpy as np

# %%
df_products = df_products.loc[np.logical_and(
    df_products['value'] < 3000,
    df_products['value'] != 0
)]

# %%
# df

# %%
df_products.sort_values(by='value', ascending=False).head(1)
# Out:
#        province product_types currency  product_group_id  \
# 104451   POLSKA           NaN       zł                 2
#
#                                      product_line  value    date
# 104451  mięso wołowe bez kości (z udźca) - za 1kg   31.9  2018-5

# %%
df_products.sort_values(by='value').head(1)
# Out:
#      province product_types currency  product_group_id  \
# 4910   POLSKA           NaN       zł                 4
#
#                               product_line  value    date
# 4910  kasza gryczana prażona cała - za 1kg   0.02  2019-4

# %%
df_products.sort_values(by=['product_types', 'value'], ascending=[False, True]).groupby('product_types')['value'].max()
# Out:
# product_types
# cukier biały z buraków cukrowych, workowany - za 1kg     3.570000
# czekolada naturalna pełna bez dodatków - za 1kg         22.060000
# jaja kóże śfierze - za 666szt.                           0.450000
# koncentrat pomidorowy 30% - za 1kg                      13.380000
# mieszanka mrożona marchew i groszek - za 1kg             0.956627
# ogórki konserwowe całe 0,9l - za 1szt.                   3.520000
# sok jabłkowy, w opakowaniu kartonowym - za 1l            2.430000
# sól warzona biała workowana - za 1kg                     0.540000
# Name: value, dtype: float64

# %%
df_products = pd.read_csv(os.path.join('..', 'datasets', 'ceny_produktow_renamed.csv'), sep=';')
df_products.head()
# Out:
#               province product_types currency  product_group_id  \
# 0         PODKARPACKIE           NaN       zł                 2
# 1              ŁÓDZKIE           NaN       zł                 4
# 2   KUJAWSKO-POMORSKIE           NaN       zł                 2
# 3         DOLNOŚLĄSKIE           NaN       zł                 2
# 4  WARMIŃSKO-MAZURSKIE           NaN       zł                 2
#
#                          product_line  value     date
# 0  szynka wieprzowa gotowana - za 1kg  21.37   2013-3
# 1                      chleb - za 1kg    NaN   2018-2
# 2  kiszka kaszana jęczmienna - za 1kg   3.55  2019-12
# 3        kurczęta patroszone - za 1kg   6.14   2019-2
# 4            salceson Włoski - za 1kg   5.63   2002-3

# %%
rows = df_products.loc[df_products.duplicated(keep='first')].shape[0]
rows
# Out:
# 21420

# %%
df_products.shape[0] - rows
# Out:
# 128520

# %%
df_products.drop_duplicates(keep='first').shape[0]
# Out:
# 128520

# %%
df_products['date'] = df_products['date'].astype(str)

# %%
df_products.loc[df_products['date'] == '1888-0', 'date'] = '1999-1'

# %%
df_products.loc[df_products['date'] == '1888-0']
# Out:
# Empty DataFrame
# Columns: [province, product_types, currency, product_group_id, product_line, value, date]
# Index: []

# %%
df_products.loc[df_products['date'] == '2099-13', 'date'] = '2019-1'

# %%
df_products['product_types'].unique()
# Out:
# array([nan, 'ogórki konserwowe całe 0,9l - za 1szt.',
#        'jaja kóże śfierze - za 666szt.',
#        'koncentrat pomidorowy 30% - za 1kg',
#        'mieszanka mrożona marchew i groszek - za 1kg',
#        'cukier biały z buraków cukrowych, workowany - za 1kg',
#        'sok jabłkowy, w opakowaniu kartonowym - za 1l',
#        'sól warzona biała workowana - za 1kg',
#        'czekolada naturalna pełna bez dodatków - za 1kg'], dtype=object)

# %%
df_products
# Out:
#                    province  \
# 0              PODKARPACKIE
# 1                   ŁÓDZKIE
# 2        KUJAWSKO-POMORSKIE
# 3              DOLNOŚLĄSKIE
# 4       WARMIŃSKO-MAZURSKIE
# ...                     ...
# 149935   KUJAWSKO-POMORSKIE
# 149936              ŁÓDZKIE
# 149937          MAŁOPOLSKIE
# 149938  WARMIŃSKO-MAZURSKIE
# 149939          MAZOWIECKIE
#
#                                             product_types currency  \
# 0                                                     NaN       zł
# 1                                                     NaN       zł
# 2                                                     NaN       zł
# 3                                                     NaN       zł
# 4                                                     NaN       zł
# ...                                                   ...      ...
# 149935                                                NaN       zł
# 149936  cukier biały z buraków cukrowych, workowany - ...       zł
# ...

# %%
df_products.loc[df_products['date'] == '1999-1']
# Out:
#                    province                                  product_types  \
# 133     WARMIŃSKO-MAZURSKIE                                            NaN
# 301      KUJAWSKO-POMORSKIE                                            NaN
# 1110              PODLASKIE                                            NaN
# 1515                 POLSKA                                            NaN
# 1637               OPOLSKIE                                            NaN
# ...                     ...                                            ...
# 147429            LUBELSKIE                                            NaN
# 147967         PODKARPACKIE                                            NaN
# 148302         DOLNOŚLĄSKIE                                            NaN
# 148611         DOLNOŚLĄSKIE  sok jabłkowy, w opakowaniu kartonowym - za 1l
# 148810       ŚWIĘTOKRZYSKIE                                            NaN
#
#        currency  product_group_id  \
# ...

# %%
df_products.loc[df_products['product_types'] == 'jaja kóże śfierze - za 666szt.', 'product_types'] = 'jaja kurze świeże - za 10szt.'

# %%
is_eur = df_products['currency'] == 'EUR'

# %%
df_products.loc[is_eur, 'currency']
# Out:
# 26        EUR
# 61        EUR
# 103       EUR
# 113       EUR
# 136       EUR
#          ...
# 149795    EUR
# 149837    EUR
# 149854    EUR
# 149863    EUR
# 149879    EUR
# Name: currency, Length: 4284, dtype: object

# %%
df_products['value'].astype(float)
# Out:
# 0         21.37
# 1           NaN
# 2          3.55
# 3          6.14
# 4          5.63
#           ...
# 149935    12.15
# 149936     0.00
# 149937     3.05
# 149938    11.87
# 149939     0.16
# Name: value, Length: 149940, dtype: float64

# %%
df_products.loc[is_eur, 'value'] = df_products['value'] * 4.15

# %%
df_products.loc[is_eur, 'currency'] = 'zł'

# %%
df_products.loc[:, 'currency'].unique()
# Out:
# array(['zł'], dtype=object)

# %%
df_products = df_products.loc[df_products['value'] != 3000]

# %%
df_products.to_csv(os.path.join('..', 'datasets', 'ceny_produktow_cleaned.csv'), sep=";", index=False)

# %% [markdown]
# ---

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'ceny_produktow_cleaned.csv'), sep=';')
df.head()
# Out:
#               province product_types currency  product_group_id  \
# 0         PODKARPACKIE           NaN       zł                 2
# 1              ŁÓDZKIE           NaN       zł                 4
# 2   KUJAWSKO-POMORSKIE           NaN       zł                 2
# 3         DOLNOŚLĄSKIE           NaN       zł                 2
# 4  WARMIŃSKO-MAZURSKIE           NaN       zł                 2
#
#                          product_line  value     date
# 0  szynka wieprzowa gotowana - za 1kg  21.37   2013-3
# 1                      chleb - za 1kg    NaN   2018-2
# 2  kiszka kaszana jęczmienna - za 1kg   3.55  2019-12
# 3        kurczęta patroszone - za 1kg   6.14   2019-2
# 4            salceson Włoski - za 1kg   5.63   2002-3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149923 entries, 0 to 149922
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   province          149923 non-null  object
#  1   product_types     34255 non-null   object
#  2   currency          149923 non-null  object
#  3   product_group_id  149923 non-null  int64
#  4   product_line      115668 non-null  object
#  5   value             137071 non-null  float64
#  6   date              149923 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 8.0+ MB

# %%
df.loc[np.logical_and(
    df['product_types'].isnull(),
    df['product_line'].isnull()
)].shape[0]
# Out:
# 0

# %%
df.sample(50)
# Out:
#                    province  \
# 95092               ŁÓDZKIE
# 87734                POLSKA
# 85641              OPOLSKIE
# 23820           MAZOWIECKIE
# 15463              LUBUSKIE
# 25375          PODKARPACKIE
# 74047          DOLNOŚLĄSKIE
# 59625          PODKARPACKIE
# 139466             OPOLSKIE
# 26791                POLSKA
# 105043        WIELKOPOLSKIE
# 45910           MAZOWIECKIE
# 98849        ŚWIĘTOKRZYSKIE
# 108323       ŚWIĘTOKRZYSKIE
# 46421   WARMIŃSKO-MAZURSKIE
# 94364              LUBUSKIE
# 78507         WIELKOPOLSKIE
# 32643             POMORSKIE
# 853            PODKARPACKIE
# 69643             POMORSKIE
# 64687             LUBELSKIE
# 114231          MAZOWIECKIE
# 106886             OPOLSKIE
# 56304         WIELKOPOLSKIE
# 94468    ZACHODNIOPOMORSKIE
# 22331          PODKARPACKIE
# 74480   WARMIŃSKO-MAZURSKIE
# 33135               ŁÓDZKIE
# 105255              ŚLĄSKIE
# 103244              ŁÓDZKIE
# 89022           MAZOWIECKIE
# 141084   ZACHODNIOPOMORSKIE
# ...

# %%
df['product'] = df['product_types']

# %%
df.loc[df['product'].isnull(), 'product'] = df['product_line']

# %%
df['product'].isnull().sum()
# Out:
# 0

# %%
df.drop_duplicates().to_csv(os.path.join('..', 'datasets', 'ceny_produktow_cleaned.csv'), sep=";", index=False)
